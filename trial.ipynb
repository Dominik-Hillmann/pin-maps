# %%
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.io.shapereader as shpreader
import cartopy.io.img_tiles as cimgt
import matplotlib.pyplot as plt
import cartopy.mpl.geoaxes
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# %matplotlib inline
import numpy as np
# from vega_datasets import data as vds

# %%
m1 = plt.axes(projection=ccrs.PlateCarree())
m1.coastlines()
# Out:
# C:\Users\Dominik USER\anaconda3\envs\pin-maps\lib\site-packages\cartopy\mpl\geoaxes.py:385: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %% [markdown]
# ## Size change

# %%
fig = plt.figure(figsize=(15,15))
m3 = fig.add_subplot(projection=ccrs.PlateCarree())
m3.coastlines()
# https://stackoverflow.com/questions/25428512/draw-a-map-of-a-specific-country-with-cartopy
# https://stackoverflow.com/questions/25428512/draw-a-map-of-a-specific-country-with-cartopy
# https://scitools.org.uk/cartopy/docs/latest/gallery/hurricane_katrina.html#sphx-glr-gallery-hurricane-katrina-py

# %%
import os
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader

from PIL import Image

from matplotlib.offsetbox import AnnotationBbox, OffsetImage

# %%
width = 2000
height = 3000
dpi = 96
projection = ccrs.PlateCarree()

fig = plt.figure(figsize=(width / dpi, height / dpi), dpi = dpi, frameon = False)

file_path = os.path.join('data', 'shapefiles', 'de.shp')
shapes = list(shpreader.Reader(file_path).geometries())

ax = plt.axes(projection = projection)
#plt.title('SCHLAAAAAND')
#ax.add_geometries(
#    shapes,
#    projection,
#    edgecolor = 'none', 
#    facecolor = cfeature.COLORS['land'], 
#    # alpha=0.5
#)
# ax.coastlines(resolution='10m')
# ax.stock_img()
ax.set_extent([5.7, 15.25, 47.2, 56.2], projection)


ax.set_aspect(1.2)

#ax.add_feature(cfeature.NaturalEarthFeature(
#    'physical', 
#    'rivers_lake_centerlines', 
#    '50m', # resolution, 
#    edgecolor = cfeature.COLORS['water'], 
#    facecolor='none'
#))

# print('Getting Netherlands')
# netherlands_path = os.path.join('data', 'shapefiles', 'netherlands.shp')
# netherlands_shape = list(shpreader.Reader(netherlands_path).geometries())
# ax.add_geometries(
#     netherlands_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )

# print('Getting PL')
# poland_path = os.path.join('data', 'shapefiles', 'poland.shp')
# poland_shape = list(shpreader.Reader(poland_path).geometries())
# ax.add_geometries(
#     poland_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )


# print('Getting DK')
# dk_path = os.path.join('data', 'shapefiles', 'dk.shp')
# dk_shape = list(shpreader.Reader(dk_path).geometries())
# ax.add_geometries(
#     dk_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )
# print('Getting CH')
# ch_path = os.path.join('data', 'shapefiles', 'ch.shp')
# ch_shape = list(shpreader.Reader(ch_path).geometries())
# ax.add_geometries(
#     ch_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )
# print('Getting F')
# f_path = os.path.join('data', 'shapefiles', 'f.shp')
# f_shape = list(shpreader.Reader(f_path).geometries())
# ax.add_geometries(
#     f_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )

# print('Getting LUX')
# lux_path = os.path.join('data', 'shapefiles', 'lux.shp')
# lux_shape = list(shpreader.Reader(lux_path).geometries())
# ax.add_geometries(
#     lux_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )


# print('Getting BE')
# be_path = os.path.join('data', 'shapefiles', 'be.shp')
# be_shape = list(shpreader.Reader(be_path).geometries())
# ax.add_geometries(
#     be_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )

# print('Getting CZ')
# cz_path = os.path.join('data', 'shapefiles', 'cz.shp')
# cz_shape = list(shpreader.Reader(cz_path).geometries())
# ax.add_geometries(
#     cz_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )

# print('Getting AU')
# au_path = os.path.join('data', 'shapefiles', 'au.shp')
# au_shape = list(shpreader.Reader(au_path).geometries())
# ax.add_geometries(
#     au_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )

# print('Getting LIE')
# li_path = os.path.join('data', 'shapefiles', 'li.shp')
# li_shape = list(shpreader.Reader(li_path).geometries())
# ax.add_geometries(
#     li_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )
# print('Getting SE')
# se_path = os.path.join('data', 'shapefiles', 'se.shp')
# se_shape = list(shpreader.Reader(se_path).geometries())
# ax.add_geometries(
#     se_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )
# print('Getting IT')
# it_path = os.path.join('data', 'shapefiles', 'it.shp')
# it_shape = list(shpreader.Reader(it_path).geometries())
# ax.add_geometries(
#     it_shape,
#     projection,
#     edgecolor = 'white', 
#     facecolor = 'white',
#     zorder = 10
# )

print('Getting DE NEG')
de_neg_path = os.path.join('data', 'shapefiles', 'de-neg.shp')
de_neg_shape = list(shpreader.Reader(de_neg_path).geometries())
ax.add_geometries(
    de_neg_shape,
    projection,
    edgecolor = 'white', 
    facecolor = 'white',
    zorder = 10
)

#print('Getting Baltic sea')
#baltic_sea_path = os.path.join('data', 'shapefiles', 'baltic.shp')
#baltic_sea_shape = list(shpreader.Reader(baltic_sea_path).geometries())
#ax.add_geometries(
#    baltic_sea_shape,
#   projection,
#   edgecolor = 'white', 
#   facecolor = 'white',
#   zorder = 10
#)

#print('Getting North Sea')
#north_sea_path = os.path.join('data', 'shapefiles', 'north.shp')
#north_sea_shape = list(shpreader.Reader(north_sea_path).geometries())
#ax.add_geometries(
#    north_sea_shape,
#   projection,
#    edgecolor = 'white', 
 #   facecolor = 'white',
  #  zorder = 10
#)

# WALLPAPER IS CALIBRATED
#m = Image.open(os.path.join('data', 'wallpaper.jpg'))
#imagebox = OffsetImage(m, zoom = 1.1)
#imagebox.image.axes = ax
#ab = AnnotationBbox(imagebox, (10.5, 50.9), pad = 0, frameon = False)
#ax.add_artist(ab)

# ARTWORK
#m = Image.open(os.path.join('data', 'artwork.png'))
#imagebox = OffsetImage(m, zoom = 1.5)
#imagebox.image.axes = ax
#ab = AnnotationBbox(imagebox, (10.5, 50.9), pad = 0, frameon = False)
#ax.add_artist(ab)
background_path = os.path.join('data', 'img', 'dust.png')
background = plt.imread(background_path)
background_extent = (5.5, 15.3, 47.0, 55.5) # (west, east, south, north)
ax.imshow(background, origin = 'upper', extent = background_extent)

#ax.plot(
#    11.5, 52, 
#    marker = 'v', 
#    markersize = 12, 
#    transform = projection
#)
# TEXT
#ax.text(
#    10.5, 51.2, 
#    'Magdeburg', 
#    transform = projection, 
#    fontdict = {
#        'color': 'red', 
#        'family': 'serif', 
#        'size': 20
#    },
#    zorder = 10
#)

#img = plt.imread('emoji.png')
# print(img)
#ax.imshow(
#    img, 
#    #origin='upper', 
##    #transform = projection, 
#    extent = (11.5, 52, 11.5, 52.2),
#    zorder = 10
#)

# Control size via zoom
# EMOJI
#img = Image.open(os.path.join('data', 'emoji.png'))
#imagebox = OffsetImage(img, zoom = 0.15)
#imagebox.image.axes = ax
#ab = AnnotationBbox(imagebox, (11.6276, 52.1205), pad = 0, frameon = False)
#ax.add_artist(ab)

#m = Image.open(os.path.join('data', 'money-bag.png'))
#imagebox = OffsetImage(m, zoom = 0.4)
#imagebox.image.axes = ax
#ab = AnnotationBbox(imagebox, (13.3923, 54.0865), pad=0, frameon=False)
#ax.add_artist(ab)
#bag_path = os.path.join('data', 'money-bag.png')
#bag_img = plt.imread(bag_path)
#ax.imshow(
#    bag_img, 
#    origin = 'upper', 
#    extent = (11.6276, 11.6276 + 11.5, 51.1205,  52.1205 + 1.5), 
#    transform = projection,
#    zorder = 11
#)

pin_path = os.path.join('data', 'img', 'fulda-pin.png')
pin = plt.imread(pin_path)
#pin_extent = (9.41, 9.41 + 0.4, 50.33, 50.33 + 0.4)
pin_extent = (9.41, 9.41 + 0.6, 50.33, 50.33 + 0.5)
ax.imshow(pin, origin = 'upper', extent = pin_extent, transform = projection, zorder = 11)

pin_path = os.path.join('data', 'img', 'stuttgart-pin.png')
pin = plt.imread(pin_path)
pin_extent = (9.202620, 9.202620 + 0.6, 48.795474, 48.795474 + 0.5)
ax.imshow(pin, origin = 'upper', extent = pin_extent, transform = projection, zorder = 11)

pin_path = os.path.join('data', 'img', 'rostock-pin.png')
pin = plt.imread(pin_path)
pin_extent = (12.099246, 12.099246 + 0.5, 54.122477, 54.122477 + 0.5)
ax.imshow(pin, origin = 'upper', extent = pin_extent, transform = projection, zorder = 11)

#plt.show()
ax.set_aspect(1.6)
plt.savefig(os.path.join('output', 'test.png'))

# https://www.diva-gis.org/gdata
# Out:
# Getting DE NEG
